# %%
import pandas as pd
import numpy as np

# %%
#Import the CSV file.
df = pd.read_csv('crypto_data.csv')
df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0          object
# CoinName            object
# Algorithm           object
# IsTrading             bool
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply     object
# dtype: object

# %%
#Filter out so that only the 'IsTrading'=True rows are kept and the 'Unnamed: 0' columns is deleted.
df = df[df['IsTrading'] == True]
df = df.drop(['Unnamed: 0', 'IsTrading'], axis = 1)
df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 1         365Coin          X11   PoW/PoS              NaN      2300000000
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 3       SixEleven      SHA-256       PoW              NaN          611000
# 4             808      SHA-256   PoW/PoS     0.000000e+00               0
# ...           ...          ...       ...              ...             ...
# 1243   Super Zero       Ethash       PoW              NaN      1000000000
# 1244          UOS      SHA-256      DPoI              NaN      1000000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [1144 rows x 5 columns]

# %%
#Check for nulls.
df.isnull().sum()
# Out:
# CoinName             0
# Algorithm            0
# ProofType            0
# TotalCoinsMined    459
# TotalCoinSupply      0
# dtype: int64

# %%
#Drop all rows with nulls.
df = df.dropna()
df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 4             808      SHA-256   PoW/PoS     0.000000e+00               0
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [685 rows x 5 columns]

# %%
#Filter out cryptocurrenct that has not been mined.
df = df[df['TotalCoinsMined'] > 0]
df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# 8        Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
# Drop the column 'CoinName' since it does not contribute to the analysis of the data.
df = df.drop(['CoinName'], axis = 1)
df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
#Convert columns `Algorithm` and `ProofType` from string to numerical data using Pandas to create dummy variables.
df_dummies = pd.get_dummies(df, columns = ['Algorithm', 'ProofType'])
df_dummies
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0        4.199995e+01              42                                 0
# 2        1.055185e+09       532000000                                 0
# 5        2.927942e+10    314159265359                                 0
# 7        1.792718e+07        21000000                                 0
# 8        1.076842e+08               0                                 0
# ...               ...             ...                               ...
# 1238     2.000000e+09      2000000000                                 0
# 1242     1.493105e+07       250000000                                 0
# 1245     9.802226e+08      1400222610                                 0
# 1246     7.296538e+06        21000000                                 0
# 1247     1.283270e+05         1000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %%
#Scale the data using StandardScaler.
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_dummies)
df_scaled
# Out:
# array([[-0.11710817, -0.1528703 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.09396955, -0.145009  , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [ 0.52494561,  4.48942416, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        ...,
#        [-0.09561336, -0.13217937, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11694817, -0.15255998, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11710536, -0.15285552, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ]])

# %%
# Initialize PCA model to 90% variance.
from sklearn.decomposition import PCA
pca = PCA(n_components=0.9)
data_pca = pca.fit_transform(df_scaled)
data_pca
# Out:
# array([[-3.35098808e-01,  1.03218907e+00, -5.90713438e-01, ...,
#          7.87306563e-16, -1.84616729e-18, -4.15361072e-15],
#        [-3.18433948e-01,  1.03233143e+00, -5.91125551e-01, ...,
#          1.17409449e-15,  5.25116470e-16, -3.80497340e-15],
#        [ 2.30546811e+00,  1.65638302e+00, -6.83616670e-01, ...,
#          2.75207903e-14, -2.36464424e-14,  2.84400186e-14],
#        ...,
#        [ 3.24348535e-01, -2.31230764e+00,  4.21515366e-01, ...,
#          1.93578889e-14, -8.67896697e-15, -3.66917605e-14],
#        [-1.49363652e-01, -2.04933553e+00,  4.12968257e-01, ...,
#         -1.78255127e-15, -2.03579310e-16, -4.38160754e-16],
#        [-2.89957500e-01,  8.21194511e-01, -2.76326847e-01, ...,
#         -4.70588149e-16, -9.07306180e-17, -2.78763670e-15]])

# %%
#Check the variance of each feature.
pca.explained_variance_ratio_
# Out:
# array([0.0279317 , 0.02141802, 0.02051615, 0.02044661, 0.0204466 ,
#        0.0204466 , 0.0204466 , 0.02042554, 0.01870913, 0.01756291,
#        0.01741106, 0.01629007, 0.01596154, 0.01551138, 0.01435005,
#        0.01321122, 0.01236583, 0.01206255, 0.01104295, 0.01071499,
#        0.01049079, 0.01040887, 0.01039089, 0.01037741, 0.01035414,
#        0.01034034, 0.01029605, 0.01028233, 0.01028139, 0.01028139,
#        0.01028138, 0.01027965, 0.01027051, 0.01026331, 0.01026202,
#        0.01025761, 0.01025565, 0.01025068, 0.01024924, 0.01024279,
#        0.01024259, 0.01024259, 0.0102419 , 0.01024018, 0.01023676,
#        0.01023495, 0.01023   , 0.01022442, 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
# ...

# %%
#Create the above array into a pandas dataFrame.
pca_df = pd.DataFrame(data=data_pca)
pca_df
# Out:
#            0         1         2         3             4             5   \
# 0   -0.335099  1.032189 -0.590713  0.001397  2.734816e-12 -5.417255e-15
# 1   -0.318434  1.032331 -0.591126  0.001386  2.712386e-12 -5.575109e-15
# 2    2.305468  1.656383 -0.683617  0.004731  9.322259e-12 -6.700325e-15
# 3   -0.145184 -1.320593  0.192813 -0.001229 -2.420624e-12  2.357806e-15
# 4   -0.151768 -2.036192  0.396182 -0.001705 -3.352037e-12  2.706411e-15
# ..        ...       ...       ...       ...           ...           ...
# 527  2.471251  0.822241 -0.071160 -0.008206 -1.632875e-11 -2.711489e-16
# 528 -0.333144  1.032071 -0.590740  0.001399  2.739500e-12 -5.504781e-15
# 529  0.324349 -2.312308  0.421515 -0.001319 -2.587411e-12  3.997274e-15
# 530 -0.149364 -2.049336  0.412968 -0.001745 -3.429876e-12  4.424198e-15
# 531 -0.289957  0.821195 -0.276327  0.000555  1.083100e-12 -2.978278e-15
#
#                6         7         8         9   ...            64  \
# ...

# %%
#Initilize the t-SNE model.
from sklearn.manifold import TSNE
tsne = TSNE(learning_rate=750)
tsne_features = tsne.fit_transform(pca_df)
tsne_features.shape
# Out:
# /Users/novakradovic/opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# (532, 2)

# %%
#Plot the t-SNE selected features to see if there are clearly visibly clusters, which there are not.
import matplotlib.pyplot as plt
plt.scatter(tsne_features[:,0], tsne_features[:,1])
plt.show()

# %%
from sklearn.cluster import KMeans
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(tsne_features)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head()
# Out:
#    k        inertia
# 0  1  261922.140625
# 1  2  149143.265625
# 2  3   92426.960938
# 3  4   51868.007812
# 4  5   34179.964844

# %%
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for customer data')
plt.show()

# %% [markdown]
# ### Recommendation
#     Based on the results of the fitted data in the PCA and then t-SNE model, the data is not clearly seperated into clusters, which in this case would be 5 by looking at the elbow curve where k=5.
